# %%
import pandas as pd
import numpy as np
import copy

from scipy.stats import chi2_contingency
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

demos = pd.read_csv("demos.csv")

# %%
demos['player_loadout_array'] = demos['player_loadout'].str.split(', ')
unique_items = demos['player_loadout_array'].explode().unique().tolist()
knives = [i for i in unique_items if
          "knife" in i.lower() or
          "daggers" in i.lower() or
          "bayonet" in i.lower() or
          "karambit" in i.lower()]

knives
# Out:
# ['Butterfly Knife',
#  'Talon Knife',
#  'M9 Bayonet',
#  'Karambit',
#  'Shadow Daggers',
#  'Skeleton Knife',
#  'Flip Knife',
#  'Bayonet',
#  'Survival Knife',
#  'Nomad Knife',
#  'Stiletto Knife',
#  'knife_t',
#  'knife',
#  'Ursus Knife']

# %%
demos['player_loadout_array'] = demos['player_loadout_array'].apply(lambda l: [i for i in l if i not in knives])
demos['player_loadout_array'].head(10)
# Out:
# 0              [Glock-18, C4 Explosive]
# 1    [Glock-18, Smoke Grenade, Molotov]
# 2                            [Glock-18]
# 3      [P250, Smoke Grenade, Flashbang]
# 4                               [USP-S]
# 5                [P2000, Smoke Grenade]
# 6                       [Dual Berettas]
# 7                               [USP-S]
# 8                    [USP-S, Flashbang]
# 9                            [Glock-18]
# Name: player_loadout_array, dtype: object

# %%
outliar_rounds = demos.loc[demos['player_loadout_array'].str.len() == 0]['round_id'].values
print(outliar_rounds)

demos_inventory = demos.loc[demos['round_id'].isin(outliar_rounds) == False]
# Out:
# [ 258  454  701 1265]

# %%
item_types = demos_inventory['player_loadout_array'].explode().unique()
item_types
# Out:
# array(['Glock-18', 'C4 Explosive', 'Smoke Grenade', 'Molotov', 'P250',
#        'Flashbang', 'USP-S', 'P2000', 'Dual Berettas', 'Tec-9',
#        'Desert Eagle', 'MP9', 'Incendiary Grenade',
#        'High Explosive Grenade', 'FAMAS', 'AK-47', 'M4A1-S', 'M4A4',
#        'AWP', 'Galil AR', 'Five-SeveN', 'Decoy Grenade', 'MAC-10', 'AUG',
#        'Zeus x27', 'SSG 08', 'XM1014', 'MAG-7', 'SG 553', 'CZ75-Auto',
#        'MP7', 'MP5-SD', 'UMP-45'], dtype=object)

# %%
secondaries = ['Glock-18', 'P250', 'USP-S', 'P2000', 'Dual Berettas', 'Tec-9',
       'Desert Eagle', 'CZ75-Auto', 'Five-SeveN']

primaries = ['MP9', 'FAMAS', 'AK-47', 'M4A1-S', 'M4A4',
       'AWP', 'Galil AR', 'MAC-10', 'AUG',
       'SSG 08', 'XM1014', 'MAG-7', 'SG 553', 
       'MP7', 'MP5-SD', 'UMP-45']

primary_ser = demos_inventory['player_loadout_array'].apply(lambda x: list(filter(lambda y: y is not None, [(item if item in primaries else None) for item in x]))).apply(lambda x: x[0] if len(x) > 0 else None)
demos_inventory = demos_inventory.assign(primary_weapon=primary_ser)

secondary_ser = demos_inventory['player_loadout_array'].apply(lambda x: list(filter(lambda y: y is not None, [(item if item in secondaries else None) for item in x]))).apply(lambda x: x[0] if len(x) > 0 else None)
demos_inventory = demos_inventory.assign(secondary_weapon=secondary_ser)

weapon_ser = np.where(demos_inventory['primary_weapon'].notna(), demos_inventory['primary_weapon'], demos_inventory['secondary_weapon'])
demos_inventory = demos_inventory.assign(weapon=weapon_ser)


demos_inventory.loc[demos_inventory['weapon'].isna()]
# Out:
#        match_id  map_id  round_id           team_name    map_name  \
# 5694         13      29       569        Team Falcons  de_ancient
# 6114         13      31       611        Team Falcons    de_dust2
# 6559         14      33       655  Lynn Vision Gaming   de_anubis
# 8476         18      43       847               FURIA     de_nuke
# 9260         20      47       926        Team Falcons    de_dust2
# 12249        25      61      1224         GamerLegion     de_nuke
# 13375        27      67      1337       Team Vitality  de_inferno
#
#        round_number  round_ct_team round_first_site_hit  round_site_hit_time  \
# 5694             15         HEROIC                    A            67.312500
# 6114              6         HEROIC                    A            51.781250
# 6559             11          FURIA                    B            34.828125
# 8476             12          FURIA                    B            34.359375
# 9260              9           MOUZ                    B            86.031250
# 12249            18   Team Falcons                  NaN                  NaN
# 13375             1  Team Vitality                    A            44.703125
#
#       round_bomb_plant_site  ...  round_first_killer  round_first_death  \
# 5694                      A  ...               False              False
# 6114                    NaN  ...               False              False
# 6559                      B  ...               False              False
# 8476                      A  ...               False              False
# 9260                      B  ...               False              False
# 12249                     A  ...               False              False
# 13375                   NaN  ...               False              False
#
#        player_headshots  player_upperbodyshots  player_stomachshots  \
# 5694                  0                      0                    0
# 6114                  0                      0                    0
# 6559                  0                      1                    0
# 8476                  0                      0                    0
# 9260                  0                      0                    0
# 12249                 0                     10                    2
# 13375                 0                      0                    0
#
#       player_legshots        player_loadout_array primary_weapon  \
# 5694                0              [C4 Explosive]           None
# 6114                0  [Smoke Grenade, Flashbang]           None
# 6559                0              [C4 Explosive]           None
# 8476                0  [Flashbang, Smoke Grenade]           None
# 9260                0                 [Flashbang]           None
# 12249               0             [Smoke Grenade]           None
# 13375               0                 [Flashbang]           None
#
#        secondary_weapon  weapon
# 5694               None    None
# 6114               None    None
# 6559               None    None
# 8476               None    None
# 9260               None    None
# 12249              None    None
# 13375              None    None
#
# [7 rows x 38 columns]

# %%
demos_inventory.loc[demos_inventory['weapon'].isna()]['round_id'].values
# Out:
# array([ 569,  611,  655,  847,  926, 1224, 1337])

# %%
more_outliar_rounds = demos_inventory.loc[demos_inventory['weapon'].isna()]['round_id'].values
demos_inventory = demos_inventory.loc[demos_inventory['round_id'].isin(more_outliar_rounds) == False]
demos_inventory.loc[demos_inventory['weapon'].isna()]['round_id'].values
# Out:
# array([], dtype=int64)

# %%
result = (demos_inventory['round_result'] == 'CT') & (demos_inventory['round_ct_team'] == demos_inventory['team_name']) | (demos_inventory['round_result'] == 'T') & (demos_inventory['round_ct_team'] != demos_inventory['team_name'])
demos_inventory = demos_inventory.assign(result=result) # makes it easier for us to do ARM
demos_inventory
# Out:
#        match_id  map_id  round_id      team_name    map_name  round_number  \
# 0             0       0         0    Team Liquid  de_ancient             1
# 1             0       0         0    Team Liquid  de_ancient             1
# 2             0       0         0    Team Liquid  de_ancient             1
# 3             0       0         0    Team Liquid  de_ancient             1
# 4             0       0         0      FaZe Clan  de_ancient             1
# ...         ...     ...       ...            ...         ...           ...
# 14275        28      70      1427           MOUZ  de_inferno            21
# 14276        28      70      1427  Team Vitality  de_inferno            21
# 14277        28      70      1427  Team Vitality  de_inferno            21
# 14278        28      70      1427           MOUZ  de_inferno            21
# 14279        28      70      1427           MOUZ  de_inferno            21
#
#        round_ct_team round_first_site_hit  round_site_hit_time  \
# 0          FaZe Clan                    A            23.078125
# 1          FaZe Clan                    A            23.078125
# 2          FaZe Clan                    A            23.078125
# 3          FaZe Clan                    A            23.078125
# 4          FaZe Clan                    A            23.078125
# ...              ...                  ...                  ...
# 14275  Team Vitality                  NaN                  NaN
# 14276  Team Vitality                  NaN                  NaN
# 14277  Team Vitality                  NaN                  NaN
# 14278  Team Vitality                  NaN                  NaN
# 14279  Team Vitality                  NaN                  NaN
#
#       round_bomb_plant_site  ...  round_first_death  player_headshots  \
# 0                       NaN  ...              False                 1
# 1                       NaN  ...              False                 1
# 2                       NaN  ...              False                 1
# 3                       NaN  ...              False                 0
# 4                       NaN  ...              False                 1
# ...                     ...  ...                ...               ...
# 14275                   NaN  ...              False                 0
# 14276                   NaN  ...              False                 1
# 14277                   NaN  ...              False                 0
# 14278                   NaN  ...              False                 0
# 14279                   NaN  ...              False                 0
#
#        player_upperbodyshots  player_stomachshots  player_legshots  \
# 0                          1                    1                0
# 1                          3                    2                0
# 2                          1                    0                0
# 3                          0                    0                0
# 4                          5                    0                0
# ...                      ...                  ...              ...
# 14275                      0                    0                0
# 14276                      1                    0                0
# 14277                      5                    1                1
# 14278                      0                    0                0
# 14279                      1                    0                0
#
#                                     player_loadout_array primary_weapon  \
# 0                               [Glock-18, C4 Explosive]           None
# 1                     [Glock-18, Smoke Grenade, Molotov]           None
# 2                                             [Glock-18]           None
# 3                       [P250, Smoke Grenade, Flashbang]           None
# 4                                                [USP-S]           None
# ...                                                  ...            ...
# 14275  [Glock-18, Galil AR, Smoke Grenade, Molotov, F...       Galil AR
# 14276  [Smoke Grenade, AK-47, Flashbang, Incendiary G...          AK-47
# 14277  [Five-SeveN, AK-47, Smoke Grenade, High Explos...          AK-47
# 14278  [Glock-18, AK-47, Molotov, High Explosive Gren...          AK-47
# 14279        [Glock-18, AK-47, Smoke Grenade, Flashbang]          AK-47
#
#       secondary_weapon    weapon  result
# 0             Glock-18  Glock-18   False
# 1             Glock-18  Glock-18   False
# 2             Glock-18  Glock-18   False
# 3                 P250      P250   False
# 4                USP-S     USP-S    True
# ...                ...       ...     ...
# 14275         Glock-18  Galil AR   False
# 14276       Five-SeveN     AK-47    True
# 14277       Five-SeveN     AK-47    True
# 14278         Glock-18     AK-47   False
# 14279         Glock-18     AK-47   False
#
# [14170 rows x 39 columns]

# %%
def create_baskets_df(demos_inventory: pd.DataFrame):
    baskets_df = demos_inventory.groupby(
        ['round_id', 'team_name']
        )['weapon'].apply(
            lambda x : [a for a in x] + ["win" if demos_inventory.loc[
                (demos_inventory['round_id'] == x.name[0]) & (demos_inventory['team_name'] == x.name[1])
            ]['result'].iloc[0] == True else "loss"]
        ).reset_index().rename(columns={"weapon": "basket"})
    baskets_df = pd.merge(baskets_df, demos_inventory, how="inner", on=["team_name", "round_id"])[['round_id', 'team_name', 'basket', 'result']]
    baskets_df = baskets_df.drop_duplicates(subset=['round_id', 'team_name']).reset_index()
    baskets_df = baskets_df.assign(result=baskets_df['result'].apply(lambda x: "win" if x else "loss"))
    return baskets_df

# %%
def mark_duplicates(basket: list):
    new_list = []
    counts = {}
    basket_clone = copy.deepcopy(basket)
    while len(basket_clone) != 0:
        item = basket_clone.pop(0)
        if item not in new_list:
            counts[item] = 1 if item not in counts else counts[item] + 1
            new_list += [item + "_" + str(counts[item]) if item != 'win' and item != 'loss' else item]
        else:
            new_list += [item + "_1" if item != 'win' and item != 'loss' else item]
    return new_list

# %%
def mark_duplicates_in_df(baskets_df: pd.DataFrame):
    baskets_df = baskets_df.assign(marked_basket=baskets_df['basket'].apply(mark_duplicates))
    return baskets_df

# %%
def generate_rules_df(baskets_df: pd.DataFrame, min_rounds: int):
    te = TransactionEncoder()
    te_ary = te.fit(baskets_df['marked_basket']).transform(baskets_df['marked_basket'])
    basket_df = pd.DataFrame(te_ary, columns=te.columns_)

    min_support = min_rounds / (len(baskets_df) / 2)

    frequent_itemsets = apriori(basket_df, min_support=min_support, use_colnames=True)
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

    # Filtering for rules where 'win' or 'loss' is the consequence
    winloss_rules = rules[(rules['consequents'] == {'loss'}) | (rules['consequents'] == {'win'})]
    return winloss_rules

# %%
def extract_highest(set: frozenset[str]):
    outset = {}
    for item in set:
        split = item.split('_')
        if split[0] not in outset or outset[split[0]] < split[1]:
            outset[split[0]] = split[1]
    items = []
    for item in outset:
        items += [item + "_" + str(outset[item])]
    return frozenset(items)

def process_winloss_df(winloss_rules: pd.DataFrame):
    winloss_rules = winloss_rules.assign(antecedents=winloss_rules['antecedents'].apply(extract_highest))
    winloss_rules = winloss_rules.drop_duplicates()
    winloss_rules = winloss_rules.reset_index().drop(columns=['index'])
    winloss_rules = winloss_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
    return winloss_rules

# %%
def baskets_with_rule(baskets_df: pd.DataFrame, rule: frozenset[str]):
    return baskets_df.loc[baskets_df['marked_basket'].apply(lambda x: [item in x for item in rule]).apply(all)]

def baskets_without_rule(baskets_df: pd.DataFrame, rule: frozenset[str]):
    return baskets_df.loc[baskets_df['marked_basket'].apply(lambda x: [item in x for item in rule]).apply(all).apply(lambda x : not x)]


def count_win_with(baskets_df: pd.DataFrame, rule: frozenset[str]):
    valid_baskets_df = baskets_with_rule(baskets_df, rule)
    return len(valid_baskets_df.loc[valid_baskets_df['result'] == 'win'])

def count_win_without(baskets_df: pd.DataFrame, rule: frozenset[str]):
    valid_baskets_df = baskets_without_rule(baskets_df, rule)
    return len(valid_baskets_df.loc[valid_baskets_df['result'] == 'win'])

def count_loss_with(baskets_df: pd.DataFrame, rule: frozenset[str]):
    valid_baskets_df = baskets_with_rule(baskets_df, rule)
    return len(valid_baskets_df.loc[valid_baskets_df['result'] == 'loss'])

def count_loss_without(baskets_df: pd.DataFrame, rule: frozenset[str]):
    valid_baskets_df = baskets_without_rule(baskets_df, rule)
    return len(valid_baskets_df.loc[valid_baskets_df['result'] == 'loss'])


def get_chi_square_counts(baskets_df: pd.DataFrame, rules_df: pd.DataFrame):
    rules_df = rules_df.assign(win_with=rules_df['antecedents'].apply(lambda x: count_win_with(baskets_df, x)))
    rules_df = rules_df.assign(win_without=rules_df['antecedents'].apply(lambda x: count_win_without(baskets_df, x)))
    rules_df = rules_df.assign(loss_with=rules_df['antecedents'].apply(lambda x: count_loss_with(baskets_df, x)))
    rules_df = rules_df.assign(loss_without=rules_df['antecedents'].apply(lambda x: count_loss_without(baskets_df, x)))

    return rules_df

# %%
def get_chisquare(row: pd.Series):
    chi2_table = [[row['win_with'], row['win_without']], [row['loss_with'], row['loss_without']]]
    use_correction = (row['win_with'] < 10) or (row['win_without'] < 10) or (row['loss_with'] < 10) or (row['loss_without'] < 10)
    chi2 = chi2_contingency(chi2_table, correction=use_correction)
    return (chi2.statistic, chi2.pvalue)

def get_chisquare_table(rules_df: pd.DataFrame, alpha = 0.05):
    chi2 = rules_df.apply(get_chisquare, axis=1)
    rules_df = rules_df.assign(chi2=chi2.apply(lambda x: x[0]), pvalue=chi2.apply(lambda x: x[1]))
    rules_df = rules_df.assign(chi2_result=rules_df.apply(lambda x: "dependent" if x['pvalue'] <= alpha else "independent", axis=1))
    return rules_df

# %%
def get_rules_chisquare_table(demos_df: pd.DataFrame, min_rounds, alpha):
    baskets_df = create_baskets_df(demos_df)
    baskets_df = mark_duplicates_in_df(baskets_df)

    rules_df = generate_rules_df(baskets_df, min_rounds)
    rules_df = process_winloss_df(rules_df)
    rules_df = get_chi_square_counts(baskets_df, rules_df)
    rules_df = get_chisquare_table(rules_df, alpha)
    return rules_df

# %%
get_rules_chisquare_table(demos_inventory, 20, 0.05)
# Out:
#                         antecedents consequents   support  confidence  \
# 0                  (Desert Eagle_1)      (loss)  0.094566    0.788235
# 1                  (Desert Eagle_2)      (loss)  0.033169    0.817391
# 2                 (Dual Berettas_1)       (win)  0.021524    0.648936
# 3                    (Five-SeveN_1)      (loss)  0.051517    0.789189
# 4                    (Five-SeveN_2)      (loss)  0.027170    0.810526
# ..                              ...         ...       ...         ...
# 63       (AWP_1, M4A1-S_1, AK-47_2)       (win)  0.038462    0.685535
# 64         (AWP_1, AK-47_2, M4A4_1)       (win)  0.021524    0.701149
# 65  (AK-47_2, Galil AR_1, MAC-10_1)       (win)  0.015526    0.698413
# 66      (AK-47_2, M4A1-S_1, M4A4_1)       (win)  0.015526    0.785714
# 67        (MP9_1, M4A1-S_1, M4A4_1)       (win)  0.018701    0.630952
#
#         lift  win_with  win_without  loss_with  loss_without        chi2  \
# 0   1.575359        72         1344        268          1150  128.077505
# 1   1.633630        21         1395         94          1324   48.191733
# 2   1.298789        61         1355         33          1385    8.667486
# 3   1.577265        39         1377        146          1272   66.047056
# 4   1.619909        18         1398         77          1341   37.826912
# ..       ...       ...          ...        ...           ...         ...
# 63  1.372037       109         1307         50          1368   23.282710
# 64  1.403289        61         1355         26          1392   14.577417
# 65  1.397812        44         1372         19          1399   10.182310
# 66  1.572538        44         1372         12          1406   18.700439
# 67  1.262796        53         1363         31          1387    5.969951
#
#           pvalue chi2_result
# 0   1.079443e-29   dependent
# 1   3.865144e-12   dependent
# 2   3.239379e-03   dependent
# 3   4.402850e-16   dependent
# 4   7.730791e-10   dependent
# ..           ...         ...
# 63  1.398516e-06   dependent
# 64  1.345170e-04   dependent
# 65  1.417944e-03   dependent
# 66  1.529473e-05   dependent
# 67  1.455169e-02   dependent
#
# [68 rows x 12 columns]

# %%
# pistol rounds
pistol_round_rules = get_rules_chisquare_table(
    demos_inventory.loc[
        (demos_inventory['round_number'] == 1) 
        | (demos_inventory['round_number'] == 13)
        ], 2, 0.05)

pistol_round_rules.loc[pistol_round_rules['chi2_result'] == "dependent"]
# Out:
#                             antecedents consequents   support  confidence  \
# 0                     (Dual Berettas_1)       (win)  0.224806    0.659091
# 2                          (Glock-18_1)      (loss)  0.306202    0.612403
# 3                          (Glock-18_2)      (loss)  0.306202    0.612403
# 4                          (Glock-18_3)      (loss)  0.306202    0.612403
# 5                          (Glock-18_4)      (loss)  0.302326    0.609375
# 7                              (P250_1)      (loss)  0.131783    0.708333
# 8                             (USP-S_1)       (win)  0.302326    0.604651
# 9                             (USP-S_2)       (win)  0.302326    0.604651
# 10           (Dual Berettas_1, P2000_1)       (win)  0.069767    0.782609
# 11           (Dual Berettas_1, USP-S_1)       (win)  0.224806    0.659091
# 12           (Dual Berettas_1, USP-S_2)       (win)  0.224806    0.659091
# 13           (Dual Berettas_1, USP-S_3)       (win)  0.193798    0.657895
# 14           (Dual Berettas_1, USP-S_4)       (win)  0.127907    0.622642
# 19                 (Glock-18_1, P250_1)      (loss)  0.131783    0.708333
# 20                 (Glock-18_2, P250_1)      (loss)  0.131783    0.708333
# 21                 (Glock-18_3, P250_1)      (loss)  0.131783    0.708333
# 22                 (Glock-18_4, P250_1)      (loss)  0.127907    0.702128
# 27  (Dual Berettas_1, P2000_1, USP-S_1)       (win)  0.069767    0.782609
# 28  (Dual Berettas_1, P2000_1, USP-S_2)       (win)  0.069767    0.782609
#
#         lift  win_with  win_without  loss_with  loss_without       chi2  \
# 0   1.328480        58           70         30           100  14.188557
# 2   1.215385        50           78         79            51  12.155769
# 3   1.215385        50           78         79            51  12.155769
# 4   1.215385        50           78         79            51  12.155769
# 5   1.209375        50           78         78            52  11.310176
# 7   1.405769        14          114         34            96   9.861279
# 8   1.218750        78           50         51            79  12.155769
# 9   1.218750        78           50         51            79  12.155769
# 10  1.577446        18          110          5           125   7.079834
# 11  1.328480        58           70         30           100  14.188557
# 12  1.328480        58           70         30           100  14.188557
# 13  1.326069        50           78         26           104  11.278407
# 14  1.255012        33           95         20           110   4.270993
# 19  1.405769        14          114         34            96   9.861279
# 20  1.405769        14          114         34            96   9.861279
# 21  1.405769        14          114         34            96   9.861279
# 22  1.393453        14          114         33            97   9.035558
# 27  1.577446        18          110          5           125   7.079834
# 28  1.577446        18          110          5           125   7.079834
#
#       pvalue chi2_result
# 0   0.000165   dependent
# 2   0.000489   dependent
# 3   0.000489   dependent
# 4   0.000489   dependent
# 5   0.000771   dependent
# 7   0.001688   dependent
# 8   0.000489   dependent
# 9   0.000489   dependent
# 10  0.007796   dependent
# 11  0.000165   dependent
# 12  0.000165   dependent
# 13  0.000784   dependent
# 14  0.038768   dependent
# 19  0.001688   dependent
# 20  0.001688   dependent
# 21  0.001688   dependent
# 22  0.002648   dependent
# 27  0.007796   dependent
# 28  0.007796   dependent

# %%
# normal rounds, T
t_normal_round_rules = get_rules_chisquare_table(
    demos_inventory.loc[
        ((demos_inventory['round_number'] != 1) 
        | (demos_inventory['round_number'] != 13)) &
        (demos_inventory['round_ct_team'] != demos_inventory['team_name'])
        ], 10, 0.05)

t_normal_round_rules.loc[t_normal_round_rules['chi2_result'] == "dependent"]
# Out:
#                               antecedents consequents   support  confidence  \
# 0                        (Desert Eagle_1)      (loss)  0.101623    0.761905
# 1                        (Desert Eagle_2)      (loss)  0.038814    0.820896
# 2                        (Desert Eagle_3)      (loss)  0.016937    0.774194
# 3                            (Glock-18_1)      (loss)  0.148200    0.755396
# 4                            (Glock-18_2)      (loss)  0.109386    0.767327
# 5                            (Glock-18_3)      (loss)  0.093860    0.760000
# 6                            (Glock-18_4)      (loss)  0.082569    0.754839
# 7                            (Glock-18_5)      (loss)  0.034580    0.644737
# 8                              (M4A1-S_1)       (win)  0.046577    0.725275
# 9                              (MAC-10_1)       (win)  0.102329    0.644444
# 10                             (MAC-10_2)       (win)  0.028229    0.645161
# 11                               (P250_1)      (loss)  0.052929    0.842697
# 13                              (Tec-9_1)      (loss)  0.095977    0.712042
# 14                              (Tec-9_2)      (loss)  0.058574    0.728070
# 15                              (Tec-9_3)      (loss)  0.033169    0.734375
# 16                              (Tec-9_4)      (loss)  0.015526    0.785714
# 17                    (AK-47_1, M4A1-S_1)       (win)  0.043754    0.756098
# 18                    (AK-47_1, MAC-10_1)       (win)  0.091037    0.668394
# 19                    (AK-47_1, MAC-10_2)       (win)  0.021877    0.645833
# 20                    (AK-47_1, SSG 08_1)       (win)  0.019760    0.682927
# 21                     (AK-47_1, Tec-9_1)      (loss)  0.033169    0.643836
# 22                     (AK-47_1, Tec-9_2)      (loss)  0.018349    0.702703
# 23                    (M4A1-S_1, AK-47_2)       (win)  0.040932    0.763158
# 24                    (AK-47_2, MAC-10_1)       (win)  0.067749    0.700730
# 25                    (M4A1-S_1, AK-47_3)       (win)  0.023289    0.687500
# 26                    (AK-47_3, MAC-10_1)       (win)  0.036697    0.675325
# 27                      (AWP_1, M4A1-S_1)       (win)  0.020466    0.743590
# 28                      (AWP_1, MAC-10_1)       (win)  0.014820    0.700000
# 29           (Desert Eagle_1, Glock-18_1)      (loss)  0.058574    0.892473
# 30           (Glock-18_2, Desert Eagle_1)      (loss)  0.036697    0.945455
# 31           (Glock-18_3, Desert Eagle_1)      (loss)  0.025406    0.947368
# 32           (Glock-18_4, Desert Eagle_1)      (loss)  0.017643    1.000000
# 33               (Desert Eagle_1, P250_1)      (loss)  0.019054    0.931034
# 34              (Desert Eagle_1, Tec-9_1)      (loss)  0.055752    0.759615
# 35              (Tec-9_2, Desert Eagle_1)      (loss)  0.033169    0.796610
# 36              (Tec-9_3, Desert Eagle_1)      (loss)  0.016231    0.793103
# 37           (Desert Eagle_2, Glock-18_1)      (loss)  0.023289    0.970588
# 38              (Desert Eagle_2, Tec-9_1)      (loss)  0.018349    0.764706
# 39                 (Galil AR_1, MAC-10_1)       (win)  0.061397    0.654135
# 40                 (MAC-10_2, Galil AR_1)       (win)  0.021877    0.673913
# 41                 (Galil AR_1, SSG 08_1)       (win)  0.015526    0.666667
# 43                 (Galil AR_2, MAC-10_1)       (win)  0.026817    0.633333
# 44                   (Glock-18_1, P250_1)      (loss)  0.041637    0.819444
# 45                  (Tec-9_1, Glock-18_1)      (loss)  0.037403    0.803030
# 46                  (Tec-9_2, Glock-18_1)      (loss)  0.019054    0.750000
# 47                   (Glock-18_2, P250_1)      (loss)  0.033169    0.810345
# 48                  (Glock-18_2, Tec-9_1)      (loss)  0.016231    0.884615
# 49                   (Glock-18_3, P250_1)      (loss)  0.028229    0.784314
# 50                   (Glock-18_4, P250_1)      (loss)  0.025406    0.765957
# 51                    (Tec-9_1, MAC-10_1)      (loss)  0.015526    0.709677
# 52                      (Tec-9_1, P250_1)      (loss)  0.015526    0.880000
# 53             (AK-47_1, AWP_1, M4A1-S_1)       (win)  0.019760    0.756757
# 55        (AK-47_1, Galil AR_1, MAC-10_1)       (win)  0.052929    0.681818
# 56        (AK-47_1, MAC-10_2, Galil AR_1)       (win)  0.016937    0.666667
# 57        (AK-47_1, Galil AR_2, MAC-10_1)       (win)  0.022583    0.680851
# 59             (AWP_1, M4A1-S_1, AK-47_2)       (win)  0.018349    0.742857
# 60        (AK-47_2, Galil AR_1, MAC-10_1)       (win)  0.031052    0.721311
# 61  (Tec-9_1, Desert Eagle_1, Glock-18_1)      (loss)  0.021171    0.857143
#
#         lift  win_with  win_without  loss_with  loss_without       chi2  \
# 0   1.503648        45          654        144           574  56.824322
# 1   1.620068        12          687         55           663  27.773912
# 2   1.527900         7          692         24           694   8.011235
# 3   1.490802        68          631        210           508  85.575700
# 4   1.514348        47          652        155           563  64.018662
# 5   1.499889        42          657        133           585  51.248363
# 6   1.489703        38          661        117           601  42.870075
# 7   1.272412        27          672         49           669   6.121469
# 8   1.470264        66          633         25           693  20.936460
# 9   1.306406       145          554         80           638  24.446873
# 10  1.307859        40          659         22           696   5.982451
# 11  1.663093        14          685         75           643  42.890250
# 13  1.405241        55          644        136           582  37.238117
# 14  1.436874        31          668         83           635  24.304668
# 15  1.449317        17          682         47           671  13.899666
# 16  1.550637         6          693         22           696   7.793871
# 17  1.532747        62          637         20           698  24.049021
# 18  1.354956       129          570         64           654  27.406061
# 19  1.309222        31          668         17           701   4.624872
# 20  1.384417        28          671         13           705   6.074250
# 21  1.270634        26          673         47           671   5.790350
# 22  1.386810        11          688         26           692   5.838961
# 23  1.547060        58          641         18           700  23.397899
# 24  1.420507        96          603         41           677  26.108347
# 25  1.393687        33          666         15           703   7.496584
# 26  1.369006        52          647         25           693  10.793814
# 27  1.507392        29          670         10           708  10.051349
# 28  1.419027        21          678          9           709   4.428248
# 29  1.761329        10          689         83           635  59.259383
# 30  1.865890         3          696         52           666  42.261218
# 31  1.869667         2          697         36           682  28.550396
# 32  1.973538         0          699         25           693  22.807297
# 33  1.837432         2          697         27           691  19.628846
# 34  1.499130        25          674         79           639  28.721840
# 35  1.572140        12          687         47           671  20.700183
# 36  1.565219         6          693         23           695   8.580850
# 37  1.915492         1          698         33           685  28.119119
# 38  1.509176         8          691         26           692   8.249612
# 39  1.326051        87          612         46           672  15.190804
# 40  1.366144        31          668         15           703   6.205078
# 41  1.351454        22          677         11           707   4.062923
# 43  1.283882        38          661         22           696   4.915513
# 44  1.617204        13          686         59           659  29.681469
# 45  1.584811        13          686         53           665  24.318458
# 46  1.480153         9          690         27           691   7.777309
# 47  1.599246        11          688         47           671  22.306731
# 48  1.745822         3          696         23           695  13.632303
# 49  1.547873        11          688         40           678  16.311572
# 50  1.511646        11          688         36           682  13.071736
# 51  1.400575         9          690         22           696   4.426547
# 52  1.736713         3          696         22           696  12.708240
# 53  1.534083        28          671          9           709   9.495729
# 55  1.382169        75          624         35           683  16.957091
# 56  1.351454        24          675         12           706   4.441908
# 57  1.380209        32          667         15           703   6.841388
# 59  1.505906        26          673          9           709   7.947348
# 60  1.462229        44          655         17           701  13.258912
# 61  1.691604         5          694         30           688  16.223386
#
#           pvalue chi2_result
# 0   4.765359e-14   dependent
# 1   1.363524e-07   dependent
# 2   4.648803e-03   dependent
# 3   2.229990e-20   dependent
# 4   1.232462e-15   dependent
# 5   8.138856e-13   dependent
# 6   5.849869e-11   dependent
# 7   1.335497e-02   dependent
# 8   4.747716e-06   dependent
# 9   7.638741e-07   dependent
# 10  1.444891e-02   dependent
# 11  5.789851e-11   dependent
# 13  1.045502e-09   dependent
# 14  8.223952e-07   dependent
# 15  1.928327e-04   dependent
# 16  5.242376e-03   dependent
# 17  9.391399e-07   dependent
# 18  1.649135e-07   dependent
# 19  3.151160e-02   dependent
# 20  1.371666e-02   dependent
# 21  1.611438e-02   dependent
# 22  1.567508e-02   dependent
# 23  1.317223e-06   dependent
# 24  3.227855e-07   dependent
# 25  6.181613e-03   dependent
# 26  1.018398e-03   dependent
# 27  1.522364e-03   dependent
# 28  3.534877e-02   dependent
# 29  1.381998e-14   dependent
# 30  7.986061e-11   dependent
# 31  9.129114e-08   dependent
# 32  1.790845e-06   dependent
# 33  9.403868e-06   dependent
# 34  8.355610e-08   dependent
# 35  5.371088e-06   dependent
# 36  3.397168e-03   dependent
# 37  1.140733e-07   dependent
# 38  4.076072e-03   dependent
# 39  9.717552e-05   dependent
# 40  1.273843e-02   dependent
# 41  4.383457e-02   dependent
# 43  2.661655e-02   dependent
# 44  5.091925e-08   dependent
# 45  8.165288e-07   dependent
# 46  5.290655e-03   dependent
# 47  2.323906e-06   dependent
# 48  2.223270e-04   dependent
# 49  5.373481e-05   dependent
# 50  2.997851e-04   dependent
# 51  3.538402e-02   dependent
# 52  3.640480e-04   dependent
# 53  2.059507e-03   dependent
# 55  3.823424e-05   dependent
# 56  3.506704e-02   dependent
# 57  8.906961e-03   dependent
# 59  4.815791e-03   dependent
# 60  2.712871e-04   dependent
# 61  5.629488e-05   dependent

# %%
# normal rounds, CT
ct_normal_round_rules = get_rules_chisquare_table(
    demos_inventory.loc[
        ((demos_inventory['round_number'] != 1) 
        | (demos_inventory['round_number'] != 13)) &
        (demos_inventory['round_ct_team'] == demos_inventory['team_name'])
        ], 10, 0.05)

ct_normal_round_rules = ct_normal_round_rules.loc[ct_normal_round_rules['chi2_result'] == "dependent"].sort_values(by='lift', ascending=False)
ct_normal_round_rules.loc[ct_normal_round_rules['consequents'] == {'win'}]
# Out:
#                            antecedents consequents   support  confidence  \
# 73         (AK-47_2, M4A1-S_1, M4A4_1)       (win)  0.026817    0.760000
# 28                      (AUG_1, AWP_1)       (win)  0.021171    0.750000
# 74            (AUG_1, AWP_1, M4A1-S_1)       (win)  0.016937    0.750000
# 3                              (AUG_1)       (win)  0.026817    0.745098
# 15                    (AK-47_1, AUG_1)       (win)  0.014114    0.740741
# 29                   (AUG_1, M4A1-S_1)       (win)  0.021877    0.738095
# 25                   (AK-47_2, M4A4_1)       (win)  0.049400    0.729167
# 69          (AK-47_1, MP9_1, M4A1-S_2)       (win)  0.014820    0.724138
# 68          (AK-47_1, MP9_1, M4A1-S_1)       (win)  0.023994    0.723404
# 17                    (AK-47_1, AWP_2)       (win)  0.014114    0.714286
# 83  (AWP_1, M4A1-S_1, M4A4_1, AK-47_2)       (win)  0.017643    0.714286
# 72            (AWP_1, AK-47_2, M4A4_1)       (win)  0.038814    0.696203
# 22                    (AWP_1, AK-47_2)       (win)  0.086803    0.679558
# 20                   (AK-47_1, M4A4_2)       (win)  0.033874    0.676056
# 21                    (AK-47_1, MP9_1)       (win)  0.027523    0.672414
# 45          (Dual Berettas_1, USP-S_2)       (win)  0.033169    0.671429
# 1                            (AK-47_2)       (win)  0.116443    0.670732
# 70          (AWP_1, M4A1-S_1, AK-47_2)       (win)  0.058574    0.669355
# 46          (Dual Berettas_1, USP-S_3)       (win)  0.028229    0.666667
# 4                              (AWP_2)       (win)  0.026817    0.666667
# 23                 (M4A1-S_1, AK-47_2)       (win)  0.083980    0.664804
# 7                    (Dual Berettas_1)       (win)  0.034580    0.662162
# 58                   (MP9_2, M4A1-S_2)       (win)  0.023289    0.660000
# 47          (Dual Berettas_1, USP-S_4)       (win)  0.019054    0.658537
# 71          (AWP_1, AK-47_2, M4A1-S_2)       (win)  0.022583    0.653061
# 44          (Dual Berettas_1, USP-S_1)       (win)  0.033169    0.652778
# 65            (AK-47_1, AWP_1, M4A4_2)       (win)  0.027523    0.650000
# 19                   (AK-47_1, M4A4_1)       (win)  0.095977    0.647619
# 2                            (AK-47_3)       (win)  0.033874    0.640000
# 24                 (AK-47_2, M4A1-S_2)       (win)  0.037403    0.638554
# 81           (MP9_1, M4A1-S_1, M4A4_1)       (win)  0.036697    0.626506
# 66         (AK-47_1, M4A1-S_1, M4A4_1)       (win)  0.067043    0.625000
# 64            (AK-47_1, AWP_1, M4A4_1)       (win)  0.077629    0.621469
# 59                     (MP9_1, M4A4_1)       (win)  0.045872    0.613208
# 16                    (AK-47_1, AWP_1)       (win)  0.155963    0.612188
# 18                 (AK-47_1, M4A1-S_1)       (win)  0.170078    0.608586
# 0                            (AK-47_1)       (win)  0.210303    0.606925
#
#         lift  win_with  win_without  loss_with  loss_without       chi2  \
# 73  1.501980        38          679         12           688  13.377227
# 28  1.482218        30          687         10           690   9.803995
# 74  1.482218        24          693          8           692   6.831169
# 3   1.472530        38          679         13           687  12.099544
# 15  1.463919        20          697          7           693   5.148108
# 29  1.458690        31          686         11           689   9.327746
# 25  1.441045        70          647         26           674  20.517522
# 69  1.431107        21          696          8           692   4.780265
# 68  1.429657        34          683         13           687   9.192029
# 17  1.411636        20          697          8           692   4.143991
# 83  1.411636        25          692         10           690   6.228410
# 72  1.375898        55          662         24           676  12.108835
# 22  1.343004       123          594         58           642  25.006266
# 20  1.336083        48          669         23           677   8.647658
# 21  1.328885        39          678         19           681   6.700187
# 45  1.326938        47          670         23           677   8.062157
# 1   1.325560       165          552         81           619  32.317102
# 70  1.322839        83          634         41           659  14.507315
# 46  1.317527        40          677         20           680   6.470278
# 4   1.317527        38          679         19           681   6.133205
# 23  1.313846       119          598         60           640  20.670829
# 7   1.308625        49          668         25           675   7.617414
# 58  1.304351        33          684         17           683   4.917487
# 47  1.301459        27          690         14           686   3.930193
# 71  1.290638        32          685         17           683   4.391441
# 44  1.290078        47          670         25           675   6.537799
# 65  1.284589        39          678         21           679   5.197533
# 19  1.279883       136          581         74           626  19.781370
# 2   1.264826        48          669         27           673   5.688789
# 24  1.261968        53          664         30           670   6.197420
# 81  1.238158        52          665         31           669   5.122032
# 66  1.235181        95          622         57           643   9.646053
# 64  1.228203       110          607         67           633  10.789090
# 59  1.211876        65          652         41           659   5.268145
# 16  1.209862       221          496        140           560  21.852496
# 18  1.202742       241          476        155           545  23.139222
# 0   1.199459       298          419        193           507  30.617481
#
#           pvalue chi2_result
# 73  2.546980e-04   dependent
# 28  1.741332e-03   dependent
# 74  8.958060e-03   dependent
# 3   5.043417e-04   dependent
# 15  2.327172e-02   dependent
# 29  2.257099e-03   dependent
# 25  5.908786e-06   dependent
# 69  2.878769e-02   dependent
# 68  2.430714e-03   dependent
# 17  4.178255e-02   dependent
# 83  1.257166e-02   dependent
# 72  5.018348e-04   dependent
# 22  5.714429e-07   dependent
# 20  3.274821e-03   dependent
# 21  9.640282e-03   dependent
# 45  4.519934e-03   dependent
# 1   1.309557e-08   dependent
# 70  1.396164e-04   dependent
# 46  1.096934e-02   dependent
# 4   1.326661e-02   dependent
# 23  5.454061e-06   dependent
# 7   5.780733e-03   dependent
# 58  2.658616e-02   dependent
# 47  4.742651e-02   dependent
# 71  3.611978e-02   dependent
# 44  1.056060e-02   dependent
# 65  2.261897e-02   dependent
# 19  8.682483e-06   dependent
# 2   1.707363e-02   dependent
# 24  1.279366e-02   dependent
# 81  2.362394e-02   dependent
# 66  1.897589e-03   dependent
# 64  1.021001e-03   dependent
# 59  2.171915e-02   dependent
# 16  2.944333e-06   dependent
# 18  1.506855e-06   dependent
# 0   3.142496e-08   dependent
